# %%
import ccxt
import json

# %%
kucoin = ccxt.kucoin()

# %%
currencies = kucoin.fetch_currencies()
print(json.dumps(currencies, indent=2))
# Out:
# {
#   "CSP": {
#     "id": "CSP",
#     "name": "Caspian",
#     "code": "CSP",
#     "precision": 8,
#     "info": {
#       "currency": "CSP",
#       "name": "CSP",
#       "fullName": "Caspian",
#       "precision": "8",
#       "confirms": "12",
#       "contractAddress": "0xa6446d655a0c34bc4f05042ee88170d056cbaf45",
#       "withdrawalMinSize": "5000",
#       "withdrawalMinFee": "1000",
#       "isWithdrawEnabled": true,
#       "isDepositEnabled": true,
#       "isMarginEnabled": false,
#       "isDebitEnabled": false
#     },
#     "active": true,
#     "fee": 1000.0,
#     "limits": {
#       "amount": {
#         "min": null,
#         "max": null
#       },
#       "price": {
#         "min": null,
#         "max": null
#       },
#       "cost": {
#         "min": null,
#         "max": null
#       }
#     }
#   },
#   "LOKI": {
#     "id": "LOKI",
#     "name": "Oxen",
#     "code": "LOKI",
#     "precision": 8,
#     "info": {
#       "currency": "LOKI",
# ...
