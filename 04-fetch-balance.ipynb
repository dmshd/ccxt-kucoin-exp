# %%
import os
import ccxt

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
kucoin = ccxt.kucoin(
    {
        'apiKey': os.environ.get('KCAPIKEY'),
        'secret': os.environ.get('KCSECRET'),
        'password': os.environ.get('KCPW'),
        'verbose': True
    }
)

# %%
kucoin.fetch_balance()
# Out:
# Request: GET https://openapi-v2.kucoin.com/api/v1/currencies {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate'} None
#
# ...
